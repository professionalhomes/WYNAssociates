# %% [markdown]
# ## Directory

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("/content/drive/MyDrive/vapaad gifs")

# %% [markdown]
# ## Library

# %%
import numpy as np
import matplotlib.pyplot as plt

import keras
from keras import layers

import io
import imageio
from IPython.display import Image, display
from ipywidgets import widgets, Layout, HBox

# %% [markdown]
# ## Acquire Data

# %%
# %%time

# Download and load the dataset.
fpath = keras.utils.get_file(
    "moving_mnist.npy",
    "http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy",
)
dataset = np.load(fpath)

# Swap the axes representing the number of frames and number of data samples.
dataset = np.swapaxes(dataset, 0, 1)
# We'll pick out 1000 of the 10000 total examples and use those.
dataset = dataset[:1000, ...]
# Add a channel dimension since the images are grayscale.
dataset = np.expand_dims(dataset, axis=-1)

# Split into train and validation sets using indexing to optimize memory.
indexes = np.arange(dataset.shape[0])
np.random.shuffle(indexes)
train_index = indexes[: int(0.9 * dataset.shape[0])]
val_index = indexes[int(0.9 * dataset.shape[0]) :]
train_dataset = dataset[train_index]
val_dataset = dataset[val_index]

# Normalize the data to the 0-1 range.
train_dataset = train_dataset / 255
val_dataset = val_dataset / 255


# We'll define a helper function to shift the frames, where
# `x` is frames 0 to n - 1, and `y` is frames 1 to n.
def create_shifted_frames(data):
    x = data[:, 0 : data.shape[1] - 1, :, :]
    y = data[:, 1 : data.shape[1], :, :]
    return x, y


# Apply the processing function to the datasets.
x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)

# Inspect the dataset.
print("Training Dataset Shapes: " + str(x_train.shape) + ", " + str(y_train.shape))
print("Validation Dataset Shapes: " + str(x_val.shape) + ", " + str(y_val.shape))
# Out:
# Downloading data from http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy
# 819200096/819200096 [==============================] - 29s 0us/step
# Training Dataset Shapes: (900, 19, 64, 64, 1), (900, 19, 64, 64, 1)
# Validation Dataset Shapes: (100, 19, 64, 64, 1), (100, 19, 64, 64, 1)
# CPU times: user 2.9 s, sys: 3.93 s, total: 6.82 s
# Wall time: 30.3 s

# %% [markdown]
# ## Ecoli Cellular Evolution
#
# We record this video from [this link](https://youtu.be/TqMrzbBaQrY?si=GGG7E76FCovIi3_Q).
#
# This short clip depicts a mutant E. coli strain that has had several proteins suppressed which control division, then Chlamydial proteins MreB and RodZ were added and they successfully led the E. coli to divide. Video provided by Anthony T. Maurelli, of the University of Florida's Emerging Pathogens Institute. Related mBio journal article with published results [here](https://journals.asm.org/doi/10.1128/mbio.03222-19).
#
# We are not using the medical conclusion from the paper. However, we do want to grant credits to the researchers to provide us the film. We are using the film as an image data to train our model as a demoonstration that the proposed `VAPAAD` model can learn cellular evolution. Since this is unsupervised learning task, no label or any medical advice is suggested of any sort. The task is aiming to produce a model that can learn the shape and future state of cellular evolution.

# %%
# os.chdir('/content/')

# %%
import cv2
import numpy as np

def load_and_process_video(video_path, frame_size=(64, 64)):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise FileNotFoundError("Unable to open video file. Please check the file path and permissions.")

    frames = []

    while True:
        # Read each frame; ret is a boolean indicating if the operation was successful
        ret, frame = cap.read()
        if not ret:
            break  # If no frame is read (end of video or error), exit the loop

        # Convert the frame to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Resize the frame
        resized_frame = cv2.resize(gray_frame, frame_size)

        # Expand dimensions to fit the shape (64, 64, 1)
        resized_frame = np.expand_dims(resized_frame, axis=-1)

        # Append the processed frame to the list of frames
        frames.append(resized_frame)

    # Release the video capture object and close any open windows
    cap.release()

    if len(frames) == 0:
        raise ValueError("No frames were processed. The video may be empty or corrupted.")

    # Concatenate all frames into a single numpy array
    video_array = np.stack(frames, axis=0)
    return video_array

# %%
# %%time

# Path to your video file
video_path = '/content/ecoli.mp4'
try:
    video_frames = load_and_process_video(video_path)
    print("Shape of the video array:", video_frames.shape)
except Exception as e:
    print("An error occurred:", e)
# Out:
# Shape of the video array: (906, 64, 64, 1)
# CPU times: user 8.32 s, sys: 4.08 s, total: 12.4 s
# Wall time: 2.53 s

# %%
plt.imshow(video_frames[100], cmap='gray')

# %%
import numpy as np

def create_training_data(video_frames):
    num_frames = video_frames.shape[0]
    frame_sequence_length = 19
    x_train = []
    y_train = []

    # Loop through the video frames array with steps ensuring no index out of bounds
    for i in range(0, num_frames - 2 * frame_sequence_length + 1, 5):
        # Define x_train_sample and y_train_sample
        x_train_sample = video_frames[i : i + frame_sequence_length]  # Frames from i to i+18
        y_train_sample = video_frames[i + frame_sequence_length : i + 2 * frame_sequence_length]  # Frames from i+19 to i+37

        # Append samples to lists
        x_train.append(x_train_sample)
        y_train.append(y_train_sample)

    # Convert lists to numpy arrays
    x_train = np.array(x_train)
    y_train = np.array(y_train)

    return x_train, y_train

# %%
# %%time

# Assuming video_frames is already defined and loaded
x_train, y_train = create_training_data(video_frames)

print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (174, 19, 64, 64, 1)
# y_train shape: (174, 19, 64, 64, 1)
# CPU times: user 7.13 ms, sys: 3.99 ms, total: 11.1 ms
# Wall time: 10.2 ms

# %%
from sklearn.model_selection import train_test_split

# Assuming x_train and y_train are already defined
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_val shape:", x_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# x_train shape: (139, 19, 64, 64, 1)
# y_train shape: (139, 19, 64, 64, 1)
# x_val shape: (35, 19, 64, 64, 1)
# y_val shape: (35, 19, 64, 64, 1)

# %% [markdown]
# ### Visualization

# %%
# %%time

# Construct a figure on which we will visualize the images.
fig, axes = plt.subplots(4, 5, figsize=(10, 8))

# Plot each of the sequential images for one random data example.
data_choice = np.random.choice(range(len(train_dataset)), size=1)[0]
for idx, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(train_dataset[data_choice][idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

# Print information and display the figure.
print(f"Displaying frames for example {data_choice}.")
plt.show()
# Out:
# Displaying frames for example 825.
# CPU times: user 1.23 s, sys: 251 ms, total: 1.48 s
# Wall time: 1.25 s

# %%
import matplotlib.pyplot as plt

def plot_image_sequences(x_train, y_train, num_samples=5):
    """
    Plots sequences of input and output images for a number of samples, with titles.

    Args:
    x_train (np.ndarray): Input image sequences.
    y_train (np.ndarray): Output image sequences.
    num_samples (int): Number of samples to plot.
    """
    fig, axes = plt.subplots(num_samples, 38, figsize=(38, num_samples * 2))  # Adjusted figsize for title space
    fig.suptitle("Sample Input/Output Sequence Images from Moving MNIST", fontsize=25, y=1.05)
    plt.figtext(0.5, 1.01, "First 19 frames are input sequences whereas latter 19 frames are output sequences",
                ha='center', fontsize=25, va='top')

    for i in range(num_samples):
        for j in range(19):  # Plot input images
            axes[i, j].imshow(x_train[i, j, :, :, 0], cmap='gray')
            axes[i, j].set_title(f'Frame {j + 1}', fontsize=8)
            axes[i, j].axis('off')
        for j in range(19):  # Plot output images
            axes[i, j + 19].imshow(y_train[i, j, :, :, 0], cmap='gray')
            axes[i, j + 19].set_title(f'Frame {j + 20}', fontsize=8)
            axes[i, j + 19].axis('off')

    plt.tight_layout()
    plt.show()

# %%
# %%time

# Example usage
plot_image_sequences(x_train, y_train)
# Out:
# CPU times: user 12.2 s, sys: 403 ms, total: 12.6 s
# Wall time: 12.2 s

# %%
# %%time

# Example usage
plot_image_sequences(x_train, y_train)
# Out:
# CPU times: user 10.7 s, sys: 377 ms, total: 11.1 s
# Wall time: 10.7 s

# %% [markdown]
# ## Build `VAPAAD` Model

# %%
import time
from datetime import datetime
from typing import Tuple

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


class SelfAttention(layers.Layer):
    """
    A custom self-attention layer that computes attention scores to enhance model performance by focusing on relevant parts of the input data.

    This layer creates query, key, and value representations of the input, then calculates attention scores to determine how much focus to put on each part of the input data. The output is a combination of the input and the attention mechanism's weighted focus, which allows the model to pay more attention to certain parts of the data.

    Attributes:
        query_dense (keras.layers.Dense): A dense layer for transforming the input into a query tensor.
        key_dense (keras.layers.Dense): A dense layer for transforming the input into a key tensor.
        value_dense (keras.layers.Dense): A dense layer for transforming the input into a value tensor.
        combine_heads (keras.layers.Dense): A dense layer for combining the attention heads' outputs.
    """

    def __init__(self, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)

    def build(self, input_shape: Tuple[int, ...]):
        """
        Initializes the internal dense layers based on the last dimension of the input shape, setting up the query, key, value, and combine heads layers.

        Args:
            input_shape (Tuple[int, ...]): The shape of the input tensor to the layer.
        """
        self.query_dense = layers.Dense(units=input_shape[-1])
        self.key_dense = layers.Dense(units=input_shape[-1])
        self.value_dense = layers.Dense(units=input_shape[-1])
        self.combine_heads = layers.Dense(units=input_shape[-1])

    def call(self, inputs: tf.Tensor) -> tf.Tensor:
        """
        Performs the self-attention mechanism on the input tensor and returns the combined output with a residual connection.

        Args:
            inputs (tf.Tensor): The input tensor to the self-attention layer.

        Returns:
            tf.Tensor: The output tensor after applying self-attention and combining with the input tensor through a residual connection.
        """
        # Generate query, key, value tensors
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)

        # Calculate attention scores
        scores = tf.matmul(query, key, transpose_b=True)
        distribution = tf.nn.softmax(scores)
        attention_output = tf.matmul(distribution, value)

        # Combine heads and add residual connection
        combined_output = self.combine_heads(attention_output) + inputs
        return combined_output


class VAPAAD:
    """A class to handle video processing with data augmentation and self-attention mechanisms."""

    def __init__(self, input_shape: Tuple[int, int, int]):
        self.input_shape = input_shape
        # Initialize generator and instructor models
        self.gen_main = self.build_generator()
        self.gen_aux = self.build_generator()
        self.instructor = self.build_instructor()
        # Define loss functions and optimizers
        self.cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        self.generator_optimizer = tf.keras.optimizers.Adam(1e-4)
        self.instructor_optimizer = tf.keras.optimizers.Adam(1e-4)

    def build_generator(self) -> keras.Model:
        """
        Constructs the generator model for video processing with data augmentation and self-attention.

        This method is responsible for creating a generator model that performs augmentations on input
        frames and then processes them through ConvLSTM2D layers with self-attention, finally applying a
        convolution across the time dimension to generate output frames.

        The model is part of a generative approach and could be used in tasks such as video frame prediction,
        unsupervised learning, or as a part of a Generative Adversarial Network (GAN).

        Returns:
            A Keras model that takes a sequence of frames as input, augments them via random zooming, rotations,
            and translations, and then outputs processed frames with the same sequence length as the input.

        Note: 'input_shape' should be an attribute of the class instance, and 'SelfAttention' is expected
        to be either a predefined layer in Keras or a custom implementation provided in the code.

        Example usage:
            generator = build_generator()
        """
        # Data augmentation layers intended to increase robustness and generalization
        data_augmentation = keras.Sequential(
            [
                layers.RandomZoom(height_factor=0.02, width_factor=0.02),
                layers.RandomRotation(factor=0.02),
                layers.RandomTranslation(height_factor=0.05, width_factor=0.05),
            ],
            name="data_augmentation",
        )

        # Input layer defining the shape of the input frames
        inp = layers.Input(shape=self.input_shape)
        # Apply time distributed data augmentation which applies the augmentation to each frame independently
        x = layers.TimeDistributed(data_augmentation)(inp)
        # Convolutional LSTM layer with relu activation to capture temporal features
        x = layers.ConvLSTM2D(
            filters=64,
            kernel_size=(5, 5),
            padding="same",
            return_sequences=True,
            activation="relu",
        )(x)
        # Batch normalization to help maintain the stability of the network
        x = layers.BatchNormalization()(x)
        # Self-attention layer for capturing long-range dependencies within the sequences
        x = SelfAttention()(x)
        # Conv3D layer to process the features obtained from previous layers and produce a sequence of frames
        x = layers.Conv3D(
            filters=1, kernel_size=(3, 3, 3), activation="sigmoid", padding="same"
        )(x)

        # Construct the model with the specified input and output tensors
        return keras.models.Model(inputs=inp, outputs=x)

    def build_instructor(self) -> keras.Model:
        """
        Constructs the instructor model with convolutional LSTM and fully connected layers.

        This method specifically builds a video processing instructor model that uses ConvLSTM2D layers,
        followed by self-attention, global average pooling, and dense layers to process the input frames
        and predict a one-dimensional output.

        The architecture is designed for sequential data processing ideal for video or time-series data.

        Returns:
            A compiled Keras model that takes a sequence of frames as input and outputs a
            one-dimensional tensor after processing through ConvLSTM2D, self-attention,
            and dense layers. The output can be interpreted as the probability of a certain
            class or a value depending on the final activation function used (sigmoid in this case).

        Note: 'input_shape' should be an attribute of the class instance, and 'SelfAttention' is
        assumed to be a pre-defined layer or a custom layer implemented elsewhere in the code.

        Example usage:
            model = build_instructor()
        """
        # Input layer defining the shape of the input frames
        inp = layers.Input(shape=self.input_shape)
        # Convolutional LSTM layer with relu activation
        x = layers.ConvLSTM2D(
            filters=64,
            kernel_size=(3, 3),
            padding="same",
            return_sequences=True,
            activation="relu",
        )(inp)
        # Batch Normalization layer
        x = layers.BatchNormalization()(x)
        # Self-attention layer for sequence learning
        x = SelfAttention()(x)
        # Global Average Pooling across the frames to get a feature vector
        x = layers.GlobalAveragePooling3D()(x)
        # Fully connected layers with relu activation
        x = layers.Dense(1024, activation="relu")(x)
        x = layers.Dense(512, activation="relu")(x)
        # Output layer with sigmoid activation for binary classification or regression tasks
        output = layers.Dense(1, activation="sigmoid")(x)

        # Construct the model with specified layers
        return keras.models.Model(inputs=inp, outputs=output)

    def train_step(
        self, images: tf.Tensor, future_images: tf.Tensor
    ) -> Tuple[tf.Tensor, tf.Tensor]:
        """
        Perform a single training step by updating the generator and instructor models.

        This method applies gradient descent to both the generator and the instructor models
        based on the loss computed from the real and generated images.

        Args:
            images (tf.Tensor): A tensor of input images for the current time step provided
                                to the generator model 'gen_main'.
            future_images (tf.Tensor): A tensor of target images for the future time step provided
                                    to the generator model 'gen_aux'.

        Returns:
            Tuple[tf.Tensor, tf.Tensor]: A tuple containing the loss values for the generator model
                                        ('gen_loss') and the instructor model ('inst_loss').

        Note: 'gen_optimizer' and 'inst_optimizer' should be attributes of the class instance.

        The function uses TensorFlow operations and assumes that 'gen_main', 'gen_aux', 'instructor',
        'generator_optimizer', 'instructor_optimizer', 'generator_loss', and 'instructor_loss' are
        defined as attributes of the class in which this method is implemented.
        """
        with tf.GradientTape() as gen_tape, tf.GradientTape() as inst_tape:
            # Generate outputs for both current and future inputs
            output_main = self.gen_main(images, training=True)
            output_aux = self.gen_aux(future_images, training=True)
            real_output = self.instructor(output_aux, training=True)
            fake_output = self.instructor(output_main, training=True)

            # Calculate losses for both models
            gen_loss = self.generator_loss(fake_output)
            inst_loss = self.instructor_loss(real_output, fake_output)

        # Apply gradients to update model weights
        gradients_of_gen = gen_tape.gradient(
            gen_loss, self.gen_main.trainable_variables
        )
        gradients_of_inst = inst_tape.gradient(
            inst_loss, self.instructor.trainable_variables
        )
        self.generator_optimizer.apply_gradients(
            zip(gradients_of_gen, self.gen_main.trainable_variables)
        )
        self.instructor_optimizer.apply_gradients(
            zip(gradients_of_inst, self.instructor.trainable_variables)
        )

        return gen_loss, inst_loss

    def generator_loss(self, fake_output):
        """
        Calculates the loss for the generator model based on its output for generated (fake) images.

        The loss encourages the generator to produce images that the instructor model classifies as real.
        This is achieved by comparing the generator's output for fake images against a target tensor of ones,
        indicating that the ideal output of the generator would be classified as real by the instructor model.

        Args:
        fake_output (tf.Tensor): The generator model's output logits for generated (fake) images.

        Returns:
        tf.Tensor: The loss for the generator model, encouraging it to generate more realistic images.
        """
        return self.cross_entropy(tf.ones_like(fake_output), fake_output)

    def instructor_loss(self, real_output, fake_output):
        """
        Calculates the loss for the instructor model based on its output for real and generated (fake) images.

        The loss is computed as the sum of the cross-entropy losses for the real and fake outputs. For real images,
        the target is a tensor of ones, and for fake images, the target is a tensor of zeros.

        Args:
        real_output (tf.Tensor): The instructor model's output logits for real images.
        fake_output (tf.Tensor): The instructor model's output logits for generated (fake) images.

        Returns:
        tf.Tensor: The total loss for the instructor model, combining the real and fake loss components.
        """
        # Define real_loss and fake_loss
        real_loss = self.cross_entropy(tf.ones_like(real_output), real_output)
        fake_loss = self.cross_entropy(tf.zeros_like(fake_output), fake_output)
        return real_loss + fake_loss

    def train(self, x_train, y_train, batch_size=64):
        """
        Trains the model for a specified batch size.

        This function iterates over the entire dataset for a epoch,
        randomly selecting batches of data to perform training steps. The selection is random
        and without replacement within each epoch, ensuring diverse exposure of data.

        Args:
        x_train (np.ndarray): The input training data.
        y_train (np.ndarray): The target training data.
        batch_size (int, optional): The number of samples per batch of computation. Defaults to 64.

        Returns:
        None
        """
        n_samples = x_train.shape[0]
        start = time.time()
        indices = np.arange(n_samples)
        np.random.shuffle(indices)
        for i in range(0, n_samples, batch_size):
            if i + batch_size > n_samples:
                continue  # Avoid index error on the last batch if it's smaller than the batch size
            selected_indices = indices[i : i + batch_size]
            x_batch = x_train[selected_indices]
            y_batch = y_train[selected_indices]
            curr_gen_loss, curr_inst_loss = self.train_step(x_batch, y_batch)
            if curr_gen_loss < 0.2:  # Early stopping condition
                print(f"Stopping early at epoch {i + 1}")
                return

            print(
                f"> running: current sample {i + 1}, gen_loss={curr_gen_loss}, inst_loss={curr_inst_loss}, time={time.time() - start} sec"
            )

    def __read_me__(self):
        """
        This function prints a multi-line formatted instruction manual for running a VAPAAD model.

        The instructions include how to inspect the data shapes of training and validation datasets,
        initializing the VAPAAD model, selecting a random subset of the training data for training,
        and finally, running the model with GPU support if available.

        There are no parameters for this function and it doesn't return anything.
        It simply prints the instructional text to the console when called.
        """
        now = datetime.now()
        current_year = now.year
        print(
            f"""
            ## Instructions

            Assume you have data as the follows:

            ```py
            # Inspect the dataset.
            print("Training Dataset Shapes: " + str(x_train.shape) + ", " + str(y_train.shape))
            print("Validation Dataset Shapes: " + str(x_val.shape) + ", " + str(y_val.shape))

            # output
            # Training Dataset Shapes: (900, 19, 64, 64, 1), (900, 19, 64, 64, 1)
            # Validation Dataset Shapes: (100, 19, 64, 64, 1), (100, 19, 64, 64, 1)
            ```

            To run the model, execute the following:
            ```py
            # Initializing a new VAPAAD model
            vapaad_model = VAPAAD(input_shape=(19, 64, 64, 1))

            # Assuming x_train and y_train are already defined and loaded
            num_samples = 64
            indices = np.random.choice(x_train.shape[0], num_samples, replace=True)
            print(indices[0:6])
            x_train_sub = x_train[indices]
            y_train_sub = y_train[indices]
            print(x_train_sub.shape, y_train_sub.shape)

            # Example usage:
            BATCH_SIZE = 3
            if tf.test.gpu_device_name() != '':
                with tf.device('/device:GPU:0'):
                    vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)
            else:
                vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)
            ```

            Copyright © 2010-{current_year} Present Yiqiao Yin
            """
        )

# %% [markdown]
# ## Get Ready for Training

# %%
# Inspect the dataset.
print("Training Dataset Shapes: " + str(x_train.shape) + ", " + str(y_train.shape))
print("Validation Dataset Shapes: " + str(x_val.shape) + ", " + str(y_val.shape))
# Out:
# Training Dataset Shapes: (695, 19, 64, 64, 1), (695, 19, 64, 64, 1)
# Validation Dataset Shapes: (174, 19, 64, 64, 1), (174, 19, 64, 64, 1)

# %% [markdown]
# ### Convert to `16bit` data

# %%
# Convert the data to a smaller data type to reduce memory usage
x_train = x_train.astype(np.float16)
y_train = y_train.astype(np.float16)

# %%
# Check gpu
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# Assuming x_train and y_train are already defined and loaded
num_samples = 64
indices = np.random.choice(x_train.shape[0], num_samples, replace=False)
print(indices[0:6])
x_train_sub = x_train[indices]
y_train_sub = y_train[indices]
print(x_train_sub.shape, y_train_sub.shape)
# Out:
# [ 74 507 479 693 550 467]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)

# %% [markdown]
# ## Define model: `VAPAAD`

# %%
# Initializing a new VAPAAD model
vapaad_model = VAPAAD(input_shape=(19, 64, 64, 1))

# %%
# readme
vapaad_model.__read_me__()
# Out:
#             ## Instructions
#
#             Assume you have data as the follows:
#
#             ```py
#             # Inspect the dataset.
#             print("Training Dataset Shapes: " + str(x_train.shape) + ", " + str(y_train.shape))
#             print("Validation Dataset Shapes: " + str(x_val.shape) + ", " + str(y_val.shape))
#
#             # output
#             # Training Dataset Shapes: (900, 19, 64, 64, 1), (900, 19, 64, 64, 1)
#             # Validation Dataset Shapes: (100, 19, 64, 64, 1), (100, 19, 64, 64, 1)
#             ```
#
#             To run the model, execute the following:
#             ```py
#             # Initializing a new VAPAAD model
#             vapaad_model = VAPAAD(input_shape=(19, 64, 64, 1))
#
#             # Assuming x_train and y_train are already defined and loaded
#             num_samples = 64
#             indices = np.random.choice(x_train.shape[0], num_samples, replace=True)
#             print(indices[0:6])
#             x_train_sub = x_train[indices]
#             y_train_sub = y_train[indices]
#             print(x_train_sub.shape, y_train_sub.shape)
#
#             # Example usage:
#             BATCH_SIZE = 3
#             if tf.test.gpu_device_name() != '':
#                 with tf.device('/device:GPU:0'):
#                     vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)
#             else:
#                 vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)
#             ```
#
#             Copyright © 2010-2024 Present Yiqiao Yin

# %% [markdown]
# ### Train

# %%
# %%time

# Epochs
NUM_OF_EP = 1

# Training
for iii in range(NUM_OF_EP):

    # Assuming x_train and y_train are already defined and loaded
    num_samples = 32
    indices = np.random.choice(x_train.shape[0], num_samples, replace=True)
    print(indices[0:6])
    x_train_sub = x_train[indices]
    y_train_sub = y_train[indices]
    print(x_train_sub.shape, y_train_sub.shape)

    # Example usage:
    BATCH_SIZE = 3
    if tf.test.gpu_device_name() != '':
        with tf.device('/device:GPU:0'):
            vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)
    else:
        vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)

    print("Epoch: " + str(iii+1))
# Out:
# [111  21 123  23  82 111]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.7006298899650574, inst_loss=1.3834822177886963, time=4.720492601394653 sec
# > running: current sample 4, gen_loss=0.6996534466743469, inst_loss=1.3812814950942993, time=6.3517255783081055 sec
# > running: current sample 7, gen_loss=0.7077545523643494, inst_loss=1.3740167617797852, time=7.979592323303223 sec
# > running: current sample 10, gen_loss=0.6985495686531067, inst_loss=1.3856080770492554, time=9.502512454986572 sec
# > running: current sample 13, gen_loss=0.7150557041168213, inst_loss=1.3679817914962769, time=11.01693844795227 sec
# > running: current sample 16, gen_loss=0.7112919688224792, inst_loss=1.365312099456787, time=12.539511442184448 sec
# > running: current sample 19, gen_loss=0.709580659866333, inst_loss=1.3680368661880493, time=14.066427230834961 sec
# > running: current sample 22, gen_loss=0.7321521639823914, inst_loss=1.3440144062042236, time=15.558298349380493 sec
# > running: current sample 25, gen_loss=0.7048609256744385, inst_loss=1.3724794387817383, time=17.062679290771484 sec
# > running: current sample 28, gen_loss=0.704860508441925, inst_loss=1.3675553798675537, time=18.604541301727295 sec
# Epoch: 1
# CPU times: user 18.3 s, sys: 281 ms, total: 18.6 s
# Wall time: 18.6 s

# %% [markdown]
# ### Extract generator

# %%
# Assuming you have a method to get the trained generator
trained_generator = vapaad_model.gen_main

# %% [markdown]
# ### Prediction Using Generator

# %%
# %%time

# prediction on validation set
if tf.test.gpu_device_name() != '':
    with tf.device('/device:GPU:0'):
        y_val_pred = trained_generator.predict(x_val)
else:
    y_val_pred = trained_generator.predict(x_val)

print("Shape of true y_val:", y_val.shape)
print("Shape of predicted y_val:", y_val_pred.shape)
# Out:
# 2/2 [==============================] - 1s 146ms/step
# Shape of true y_val: (35, 19, 64, 64, 1)
# Shape of predicted y_val: (35, 19, 64, 64, 1)
# CPU times: user 457 ms, sys: 57.5 ms, total: 515 ms
# Wall time: 1.06 s

# %% [markdown]
# ## Visualization

# %%
import numpy as np

def rescale_and_discretize(image):
    """
    Rescales an image to the 0-1 range and discretizes the values into levels {0.1, 0.2, ..., 0.9}.

    Args:
    image (np.ndarray): The input image to be rescaled and discretized.

    Returns:
    np.ndarray: The rescaled and discretized image.
    """
    # Rescale image to 0-1 range
    min_val = np.min(image)
    max_val = np.max(image)
    normalized_image = (image - min_val) / (max_val - min_val) if max_val > min_val else image

    # Discretize to nearest levels in {0.1, 0.2, ..., 0.9}
    Q = 32  # Number of levels
    discretized_image = np.round(normalized_image * Q) / (Q+1)  # Multiplies by 9, rounds, then divides by 10
    discretized_image = np.clip(discretized_image, 0.1, 0.9)  # Ensures values are within the specified levels

    return discretized_image

# %% [markdown]
# Moving MNIST

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure with specified dimensions
plt.figure(figsize=(20, 6))

# Randomly select 5 samples
num_samples = 2
indices = np.random.choice(y_val.shape[0], num_samples, replace=False)

# Total number of plots per sample (19 predictions + 19 actuals)
num_plots_per_sample = 19 * 2  # 19 predicted and 19 actual

# Iterate over each of the randomly selected samples
for idx, sample_index in enumerate(indices):
    # First row for y_val (true values)
    for i in range(19):
        ax = plt.subplot(num_samples * 2, 19, 2 * idx * 19 + i + 1)  # Calculate position index
        plt.imshow(y_val[sample_index, i, :, :, 0], cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title(f'Sample {sample_index+1} - True Frames')
        plt.text(0.5, -0.1, f't={i+1}', ha='center', va='center', transform=ax.transAxes, fontsize=8)  # Adding time label

    # Second row for y_val_pred (predicted values)
    for i in range(19):
        plt.subplot(num_samples * 2, 19, (2 * idx + 1) * 19 + i + 1)  # Calculate position index
        image = y_val_pred[sample_index, i, :, :, 0]
        result_image = rescale_and_discretize(image)
        plt.imshow(result_image, cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title(f'Sample {sample_index+1} - Pred Frames')

plt.tight_layout()
plt.show()

# %% [markdown]
# Ecoli

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure with specified dimensions
plt.figure(figsize=(20, 6))

# Randomly select 5 samples
num_samples = 2
indices = np.random.choice(y_val.shape[0], num_samples, replace=False)

# Total number of plots per sample (19 predictions + 19 actuals)
num_plots_per_sample = 19 * 2  # 19 predicted and 19 actual

# Iterate over each of the randomly selected samples
for idx, sample_index in enumerate(indices):
    # First row for y_val (true values)
    for i in range(19):
        ax = plt.subplot(num_samples * 2, 19, 2 * idx * 19 + i + 1)  # Calculate position index
        plt.imshow(y_val[sample_index, i, :, :, 0], cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title(f'Sample {sample_index+1} - True Frames')
        plt.text(0.5, -0.1, f't={i+1}', ha='center', va='center', transform=ax.transAxes, fontsize=8)  # Adding time label

    # Second row for y_val_pred (predicted values)
    for i in range(19):
        plt.subplot(num_samples * 2, 19, (2 * idx + 1) * 19 + i + 1)  # Calculate position index
        image = y_val_pred[sample_index, i, :, :, 0]
        result_image = rescale_and_discretize(image)
        plt.imshow(result_image, cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.title(f'Sample {sample_index+1} - Pred Frames')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Create `.gif`

# %% [markdown]
# Moving MNIST

# %%
# Create a directory for the GIFs
gif_dir = "predicted_gifs_instruct_vapaad_stop_grad"
os.makedirs(gif_dir, exist_ok=True)

# Select a few random examples from the dataset.
examples = val_dataset[np.random.choice(range(len(val_dataset)), size=5)]

# Iterate over the examples and predict the frames.
predicted_videos = []
for index, example in enumerate(examples):
    # Pick the first/last ten frames from the example.
    frames = example[:10, ...]
    original_frames = example[10:, ...]
    new_predictions = np.zeros(shape=(10, *frames[0].shape))

    # Predict a new set of 10 frames.
    for i in range(10):
        # Extract the generator's prediction and post-process it.
        frames = example[: 10 + i + 1, ...]
        new_prediction = trained_generator.predict(np.expand_dims(frames, axis=0))
        new_prediction = rescale_and_discretize(new_prediction)
        new_prediction = np.squeeze(new_prediction, axis=0)
        predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

        # Extend the set of prediction frames.
        new_predictions[i] = predicted_frame

    # Create and save GIFs for each of the ground truth/prediction images.
    for frame_set_idx, frame_set in enumerate([original_frames, new_predictions]):
        # Construct a GIF from the selected video frames.
        current_frames = np.squeeze(frame_set)
        current_frames = current_frames[..., np.newaxis] * np.ones(3)
        current_frames = (current_frames * 255).astype(np.uint8)
        current_frames = list(current_frames)

        # Define the GIF filepath
        gif_filename = os.path.join(gif_dir, f"example_{index}_{'original' if frame_set_idx == 0 else 'predicted'}.gif")

        # Save the GIF
        imageio.mimsave(gif_filename, current_frames, "GIF", duration=.9)

        # To display the videos inline, you can open and read the saved GIF
        with open(gif_filename, 'rb') as gif_file:
            predicted_videos.append(gif_file.read())

# Display the videos inline in the notebook.
print("Truth\tPrediction")
for i in range(0, len(predicted_videos), 2):
    box = HBox(
        [
            widgets.Image(value=predicted_videos[i], format='gif'),
            widgets.Image(value=predicted_videos[i + 1], format='gif'),
        ]
    )
    display(box)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 57ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf9\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfb\xfb\xfb\xfa\…

# %% [markdown]
# Ecoli

# %%
x_val[np.random.choice(range(len(x_val)), size=5)]
# Out:
# (5, 19, 64, 64, 1)

# %%
val_dataset[np.random.choice(range(len(val_dataset)), size=5)].shape
# Out:
# (5, 20, 64, 64, 1)

# %%
# Create a directory for the GIFs
gif_dir = "predicted_gifs_ecoli_instruct_vapaad_stop_grad"
os.makedirs(gif_dir, exist_ok=True)

# Select a few random examples from the dataset.
examples = x_val[np.random.choice(range(len(x_val)), size=5)]

# Iterate over the examples and predict the frames.
predicted_videos = []
for index, example in enumerate(examples):
    # Pick the first/last ten frames from the example.
    frames = example[:10, ...]
    original_frames = example[10:, ...]
    new_predictions = np.zeros(shape=(10, *frames[0].shape))

    # Predict a new set of 10 frames.
    for i in range(10):
        # Extract the generator's prediction and post-process it.
        frames = example[: 10 + i + 1, ...]
        new_prediction = trained_generator.predict(np.expand_dims(frames, axis=0))
        new_prediction = rescale_and_discretize(new_prediction)
        new_prediction = np.squeeze(new_prediction, axis=0)
        predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

        # Extend the set of prediction frames.
        new_predictions[i] = predicted_frame

    # Create and save GIFs for each of the ground truth/prediction images.
    for frame_set_idx, frame_set in enumerate([original_frames, new_predictions]):
        # Construct a GIF from the selected video frames.
        current_frames = np.squeeze(frame_set)
        current_frames = current_frames[..., np.newaxis] * np.ones(3)
        current_frames = (current_frames * 255).astype(np.uint8)
        current_frames = list(current_frames)

        # Define the GIF filepath
        gif_filename = os.path.join(gif_dir, f"example_{index}_{'original' if frame_set_idx == 0 else 'predicted'}.gif")

        # Save the GIF
        imageio.mimsave(gif_filename, current_frames, "GIF", duration=.9)

        # To display the videos inline, you can open and read the saved GIF
        with open(gif_filename, 'rb') as gif_file:
            predicted_videos.append(gif_file.read())

# Display the videos inline in the notebook.
print("Truth\tPrediction")
for i in range(0, len(predicted_videos), 2):
    box = HBox(
        [
            widgets.Image(value=predicted_videos[i], format='gif'),
            widgets.Image(value=predicted_videos[i + 1], format='gif'),
        ]
    )
    display(box)
# Out:
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xba\xba\xba\x98\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x85\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…

# %% [markdown]
# #### Moving MNIST

# %%
# %%time

# Epochs
NUM_OF_EP = 20
for iii in range(NUM_OF_EP):

    # Assuming x_train and y_train are already defined and loaded
    num_samples = 64
    indices = np.random.choice(x_train.shape[0], num_samples, replace=True)
    print(indices[0:6])
    x_train_sub = x_train[indices]
    y_train_sub = y_train[indices]
    print(x_train_sub.shape, y_train_sub.shape)

    # Example usage:
    BATCH_SIZE = 3
    if tf.test.gpu_device_name() != '':
        with tf.device('/device:GPU:0'):
            vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)
    else:
        vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)

    print("Epoch: " + str(iii+1))

    # Assuming you have a method to get the trained generator
    trained_generator = vapaad_model.gen_main

    if True:
        # Create a directory for the GIFs
        gif_dir = "predicted_gifs_ecoli_instruct_vapaad_stop_grad"
        os.makedirs(gif_dir, exist_ok=True)

        # Select a few random examples from the dataset.
        examples = x_val[np.random.choice(range(len(x_val)), size=5)]

        # Iterate over the examples and predict the frames.
        predicted_videos = []
        for index, example in enumerate(examples):
            # Pick the first/last ten frames from the example.
            frames = example[:10, ...]
            original_frames = example[10:, ...]
            new_predictions = np.zeros(shape=(10, *frames[0].shape))

            # Predict a new set of 10 frames.
            for i in range(10):
                # Extract the generator's prediction and post-process it.
                frames = example[: 10 + i + 1, ...]
                new_prediction = trained_generator.predict(np.expand_dims(frames, axis=0))
                new_prediction = rescale_and_discretize(new_prediction)
                new_prediction = np.squeeze(new_prediction, axis=0)
                predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

                # Extend the set of prediction frames.
                new_predictions[i] = predicted_frame

            # Create and save GIFs for each of the ground truth/prediction images.
            for frame_set_idx, frame_set in enumerate([original_frames, new_predictions]):
                # Construct a GIF from the selected video frames.
                current_frames = np.squeeze(frame_set)
                current_frames = current_frames[..., np.newaxis] * np.ones(3)
                current_frames = (current_frames * 255).astype(np.uint8)
                current_frames = list(current_frames)

                # Define the GIF filepath
                gif_filename = os.path.join(gif_dir, f"example_{index}_{'original' if frame_set_idx == 0 else 'predicted'}.gif")

                # Save the GIF
                imageio.mimsave(gif_filename, current_frames, "GIF", duration=.9)

                # To display the videos inline, you can open and read the saved GIF
                with open(gif_filename, 'rb') as gif_file:
                    predicted_videos.append(gif_file.read())

        # Display the videos inline in the notebook.
        print("Truth\tPrediction")
        for i in range(0, len(predicted_videos), 2):
            box = HBox(
                [
                    widgets.Image(value=predicted_videos[i], format='gif'),
                    widgets.Image(value=predicted_videos[i + 1], format='gif'),
                ]
            )
            display(box)
# Out:
# [127 204 562 813 586 831]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.6946622729301453, inst_loss=1.3778226375579834, time=1.613069772720337 sec
# > running: current sample 4, gen_loss=0.6948124766349792, inst_loss=1.377895474433899, time=3.136775255203247 sec
# > running: current sample 7, gen_loss=0.7092525362968445, inst_loss=1.3697274923324585, time=4.671069145202637 sec
# > running: current sample 10, gen_loss=0.71055668592453, inst_loss=1.3641163110733032, time=6.2038233280181885 sec
# > running: current sample 13, gen_loss=0.7231351733207703, inst_loss=1.3518891334533691, time=7.734997987747192 sec
# > running: current sample 16, gen_loss=0.7548481822013855, inst_loss=1.3274509906768799, time=9.283901691436768 sec
# > running: current sample 19, gen_loss=0.7344793677330017, inst_loss=1.339777946472168, time=10.92004680633545 sec
# > running: current sample 22, gen_loss=0.7456986308097839, inst_loss=1.3259763717651367, time=12.463809251785278 sec
# > running: current sample 25, gen_loss=0.7875054478645325, inst_loss=1.298290491104126, time=14.003039598464966 sec
# > running: current sample 28, gen_loss=0.7806975245475769, inst_loss=1.2922422885894775, time=15.550127029418945 sec
# > running: current sample 31, gen_loss=0.782038688659668, inst_loss=1.286350965499878, time=17.065768241882324 sec
# > running: current sample 34, gen_loss=0.7849729061126709, inst_loss=1.2821109294891357, time=18.612483978271484 sec
# > running: current sample 37, gen_loss=0.7840144038200378, inst_loss=1.2811256647109985, time=20.188828468322754 sec
# > running: current sample 40, gen_loss=0.7970619201660156, inst_loss=1.2697083950042725, time=22.08084988594055 sec
# > running: current sample 43, gen_loss=0.7788740992546082, inst_loss=1.2854973077774048, time=23.65183997154236 sec
# > running: current sample 46, gen_loss=0.7788362503051758, inst_loss=1.285412073135376, time=25.189171314239502 sec
# > running: current sample 49, gen_loss=0.7746474146842957, inst_loss=1.2863414287567139, time=26.730324029922485 sec
# > running: current sample 52, gen_loss=0.7476703524589539, inst_loss=1.312467098236084, time=28.28840923309326 sec
# > running: current sample 55, gen_loss=0.70906001329422, inst_loss=1.352003812789917, time=29.847158193588257 sec
# > running: current sample 58, gen_loss=0.6919611096382141, inst_loss=1.373186469078064, time=31.393538236618042 sec
# > running: current sample 61, gen_loss=0.6938104033470154, inst_loss=1.4131522178649902, time=32.93400979042053 sec
# Epoch: 1
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf9\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xfb\xfb\xfb\xfa\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfb\xfb\xfb\xfa\…
# [196  71  93 813 686 605]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.6596236824989319, inst_loss=1.4257853031158447, time=1.5556972026824951 sec
# > running: current sample 4, gen_loss=0.6601385474205017, inst_loss=1.427170991897583, time=3.0916848182678223 sec
# > running: current sample 7, gen_loss=0.6671962738037109, inst_loss=1.442381501197815, time=4.6157214641571045 sec
# > running: current sample 10, gen_loss=0.6671006083488464, inst_loss=1.4466854333877563, time=6.116411447525024 sec
# > running: current sample 13, gen_loss=0.6634588241577148, inst_loss=1.4205591678619385, time=7.643482208251953 sec
# > running: current sample 16, gen_loss=0.6598228812217712, inst_loss=1.4106037616729736, time=9.184330701828003 sec
# > running: current sample 19, gen_loss=0.6530017256736755, inst_loss=1.4155042171478271, time=10.707710981369019 sec
# > running: current sample 22, gen_loss=0.6510164141654968, inst_loss=1.3966724872589111, time=12.212042808532715 sec
# > running: current sample 25, gen_loss=0.6483327746391296, inst_loss=1.3829174041748047, time=13.71693468093872 sec
# > running: current sample 28, gen_loss=0.6414064764976501, inst_loss=1.3852676153182983, time=15.238924503326416 sec
# > running: current sample 31, gen_loss=0.6469736099243164, inst_loss=1.394575595855713, time=16.744308471679688 sec
# > running: current sample 34, gen_loss=0.6347277760505676, inst_loss=1.3830592632293701, time=18.265557527542114 sec
# > running: current sample 37, gen_loss=0.6303032040596008, inst_loss=1.3825562000274658, time=19.789480686187744 sec
# > running: current sample 40, gen_loss=0.6250936985015869, inst_loss=1.3850483894348145, time=21.308128595352173 sec
# > running: current sample 43, gen_loss=0.6234707236289978, inst_loss=1.3870635032653809, time=22.807292699813843 sec
# > running: current sample 46, gen_loss=0.6246634721755981, inst_loss=1.3896507024765015, time=24.2977876663208 sec
# > running: current sample 49, gen_loss=0.6270942091941833, inst_loss=1.392160177230835, time=26.10880398750305 sec
# > running: current sample 52, gen_loss=0.6326422095298767, inst_loss=1.403813123703003, time=27.621476650238037 sec
# > running: current sample 55, gen_loss=0.633007824420929, inst_loss=1.3893852233886719, time=29.124302864074707 sec
# > running: current sample 58, gen_loss=0.6403350830078125, inst_loss=1.3889257907867432, time=30.636188745498657 sec
# > running: current sample 61, gen_loss=0.6466869711875916, inst_loss=1.3972656726837158, time=32.19838309288025 sec
# Epoch: 2
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfa\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# [686 743 183 657 271 102]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.6576550006866455, inst_loss=1.3932554721832275, time=1.5361528396606445 sec
# > running: current sample 4, gen_loss=0.666567325592041, inst_loss=1.4020836353302002, time=3.058807611465454 sec
# > running: current sample 7, gen_loss=0.6708754897117615, inst_loss=1.3949449062347412, time=4.582880973815918 sec
# > running: current sample 10, gen_loss=0.6755738258361816, inst_loss=1.3935986757278442, time=6.084327697753906 sec
# > running: current sample 13, gen_loss=0.6881545186042786, inst_loss=1.4068963527679443, time=7.621207237243652 sec
# > running: current sample 16, gen_loss=0.6826055645942688, inst_loss=1.3989274501800537, time=9.127863883972168 sec
# > running: current sample 19, gen_loss=0.6793362498283386, inst_loss=1.393942952156067, time=10.62698221206665 sec
# > running: current sample 22, gen_loss=0.6812840104103088, inst_loss=1.4008128643035889, time=12.139248132705688 sec
# > running: current sample 25, gen_loss=0.6835454106330872, inst_loss=1.3960468769073486, time=13.647913694381714 sec
# > running: current sample 28, gen_loss=0.6927135586738586, inst_loss=1.3970203399658203, time=15.155046224594116 sec
# > running: current sample 31, gen_loss=0.6999937891960144, inst_loss=1.3908231258392334, time=16.676903247833252 sec
# > running: current sample 34, gen_loss=0.7073609232902527, inst_loss=1.3816039562225342, time=18.19796895980835 sec
# > running: current sample 37, gen_loss=0.7131077647209167, inst_loss=1.3717823028564453, time=19.784454107284546 sec
# > running: current sample 40, gen_loss=0.7207996249198914, inst_loss=1.3674590587615967, time=21.30194640159607 sec
# > running: current sample 43, gen_loss=0.7291903495788574, inst_loss=1.3602676391601562, time=22.81737208366394 sec
# > running: current sample 46, gen_loss=0.7526634335517883, inst_loss=1.3494725227355957, time=24.32538104057312 sec
# > running: current sample 49, gen_loss=0.772639274597168, inst_loss=1.3368293046951294, time=25.839578866958618 sec
# > running: current sample 52, gen_loss=0.7625476717948914, inst_loss=1.3329676389694214, time=27.408788681030273 sec
# > running: current sample 55, gen_loss=0.7870709896087646, inst_loss=1.3219234943389893, time=29.21516752243042 sec
# > running: current sample 58, gen_loss=0.777569055557251, inst_loss=1.3455898761749268, time=30.76706314086914 sec
# > running: current sample 61, gen_loss=0.780468761920929, inst_loss=1.3314824104309082, time=32.30397081375122 sec
# Epoch: 3
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf9\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xf9\xf9\xf9\xf4\…
# [ 99 340 652 705 861  42]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.812279224395752, inst_loss=1.3329432010650635, time=1.530144214630127 sec
# > running: current sample 4, gen_loss=0.8224589228630066, inst_loss=1.3441425561904907, time=3.0399932861328125 sec
# > running: current sample 7, gen_loss=0.8530089855194092, inst_loss=1.3419883251190186, time=4.557580947875977 sec
# > running: current sample 10, gen_loss=1.0164088010787964, inst_loss=1.271679162979126, time=6.092501878738403 sec
# > running: current sample 13, gen_loss=1.3380235433578491, inst_loss=1.3611021041870117, time=7.617990255355835 sec
# > running: current sample 16, gen_loss=1.2985823154449463, inst_loss=1.4040943384170532, time=9.139628887176514 sec
# > running: current sample 19, gen_loss=1.0494505167007446, inst_loss=1.412539005279541, time=10.62960958480835 sec
# > running: current sample 22, gen_loss=0.8350573182106018, inst_loss=1.4465256929397583, time=12.153441429138184 sec
# > running: current sample 25, gen_loss=0.7338718771934509, inst_loss=1.4653687477111816, time=13.673105716705322 sec
# > running: current sample 28, gen_loss=0.6905081272125244, inst_loss=1.4405031204223633, time=15.199249505996704 sec
# > running: current sample 31, gen_loss=0.6789729595184326, inst_loss=1.425497055053711, time=16.72608494758606 sec
# > running: current sample 34, gen_loss=0.6746174693107605, inst_loss=1.4250719547271729, time=18.26674246788025 sec
# > running: current sample 37, gen_loss=0.6724185943603516, inst_loss=1.3855831623077393, time=19.79838538169861 sec
# > running: current sample 40, gen_loss=0.6606529355049133, inst_loss=1.3981287479400635, time=21.365030765533447 sec
# > running: current sample 43, gen_loss=0.6606473326683044, inst_loss=1.3853068351745605, time=22.87368392944336 sec
# > running: current sample 46, gen_loss=0.6614345908164978, inst_loss=1.3838005065917969, time=24.38971185684204 sec
# > running: current sample 49, gen_loss=0.6663749814033508, inst_loss=1.3810352087020874, time=25.8696026802063 sec
# > running: current sample 52, gen_loss=0.6626588702201843, inst_loss=1.3808399438858032, time=27.37397003173828 sec
# > running: current sample 55, gen_loss=0.6770192980766296, inst_loss=1.3662002086639404, time=29.182414054870605 sec
# > running: current sample 58, gen_loss=0.6672732830047607, inst_loss=1.369418740272522, time=30.72826862335205 sec
# > running: current sample 61, gen_loss=0.6722577214241028, inst_loss=1.3735814094543457, time=32.24778652191162 sec
# Epoch: 4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x82\x00\x00\xff\xff\xff\xbf\xbf\xbf\x80\x80\x80@@@\x00\x00\x00\x…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xf9\xf9\xf9\xf7\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf7\…
# [593 474 655 683 878 157]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.6625543236732483, inst_loss=1.3664066791534424, time=1.506753921508789 sec
# > running: current sample 4, gen_loss=0.6659044027328491, inst_loss=1.3570568561553955, time=3.0145862102508545 sec
# > running: current sample 7, gen_loss=0.6600165963172913, inst_loss=1.347888469696045, time=4.529288291931152 sec
# > running: current sample 10, gen_loss=0.6492106318473816, inst_loss=1.3404827117919922, time=6.11407470703125 sec
# > running: current sample 13, gen_loss=0.6403850317001343, inst_loss=1.3330631256103516, time=7.628154277801514 sec
# > running: current sample 16, gen_loss=0.6200365424156189, inst_loss=1.3401875495910645, time=9.14926290512085 sec
# > running: current sample 19, gen_loss=0.6177294850349426, inst_loss=1.3291752338409424, time=10.674180030822754 sec
# > running: current sample 22, gen_loss=0.6195853352546692, inst_loss=1.3117629289627075, time=12.196898937225342 sec
# > running: current sample 25, gen_loss=0.6081526279449463, inst_loss=1.329425573348999, time=13.736811399459839 sec
# > running: current sample 28, gen_loss=0.6014685034751892, inst_loss=1.328031063079834, time=15.28200364112854 sec
# > running: current sample 31, gen_loss=0.5939149856567383, inst_loss=1.3309171199798584, time=16.83184027671814 sec
# > running: current sample 34, gen_loss=0.5817103385925293, inst_loss=1.3398146629333496, time=18.37990641593933 sec
# > running: current sample 37, gen_loss=0.5766549706459045, inst_loss=1.3363542556762695, time=19.89073157310486 sec
# > running: current sample 40, gen_loss=0.5585135221481323, inst_loss=1.3670473098754883, time=21.3898344039917 sec
# > running: current sample 43, gen_loss=0.5879508256912231, inst_loss=1.364336371421814, time=22.907520532608032 sec
# > running: current sample 46, gen_loss=0.5832006931304932, inst_loss=1.3772364854812622, time=24.408365488052368 sec
# > running: current sample 49, gen_loss=0.5908560156822205, inst_loss=1.3749783039093018, time=25.920714616775513 sec
# > running: current sample 52, gen_loss=0.5757198929786682, inst_loss=1.3927419185638428, time=27.73762607574463 sec
# > running: current sample 55, gen_loss=0.612246572971344, inst_loss=1.384264349937439, time=29.27965545654297 sec
# > running: current sample 58, gen_loss=0.6152879595756531, inst_loss=1.3894888162612915, time=30.822134256362915 sec
# > running: current sample 61, gen_loss=0.6560385823249817, inst_loss=1.3903448581695557, time=32.32994508743286 sec
# Epoch: 5
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# [167 457 773 567 522 825]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.6626901030540466, inst_loss=1.3896925449371338, time=1.5230634212493896 sec
# > running: current sample 4, gen_loss=0.6635494232177734, inst_loss=1.3891830444335938, time=3.027451753616333 sec
# > running: current sample 7, gen_loss=0.6648775339126587, inst_loss=1.3898711204528809, time=4.579466342926025 sec
# > running: current sample 10, gen_loss=0.6661702990531921, inst_loss=1.3915389776229858, time=6.096958875656128 sec
# > running: current sample 13, gen_loss=0.6716499924659729, inst_loss=1.3865753412246704, time=7.605161190032959 sec
# > running: current sample 16, gen_loss=0.6745854020118713, inst_loss=1.3826868534088135, time=9.12685489654541 sec
# > running: current sample 19, gen_loss=0.6724936366081238, inst_loss=1.3911947011947632, time=10.636467218399048 sec
# > running: current sample 22, gen_loss=0.6739237904548645, inst_loss=1.387526512145996, time=12.141906261444092 sec
# > running: current sample 25, gen_loss=0.6759708523750305, inst_loss=1.3852136135101318, time=13.64176058769226 sec
# > running: current sample 28, gen_loss=0.6773049235343933, inst_loss=1.3847620487213135, time=15.164146661758423 sec
# > running: current sample 31, gen_loss=0.6873947978019714, inst_loss=1.3884071111679077, time=16.73677396774292 sec
# > running: current sample 34, gen_loss=0.6924958229064941, inst_loss=1.3831417560577393, time=18.246607303619385 sec
# > running: current sample 37, gen_loss=0.7032716870307922, inst_loss=1.3850659132003784, time=19.735843896865845 sec
# > running: current sample 40, gen_loss=0.7067449688911438, inst_loss=1.3833870887756348, time=21.242210626602173 sec
# > running: current sample 43, gen_loss=0.7112160325050354, inst_loss=1.3839284181594849, time=22.753660678863525 sec
# > running: current sample 46, gen_loss=0.722926914691925, inst_loss=1.3783185482025146, time=24.262953519821167 sec
# > running: current sample 49, gen_loss=0.7398433685302734, inst_loss=1.3769017457962036, time=25.75923180580139 sec
# > running: current sample 52, gen_loss=0.7355794906616211, inst_loss=1.3780581951141357, time=27.27287983894348 sec
# > running: current sample 55, gen_loss=0.7497469782829285, inst_loss=1.3718430995941162, time=28.792144060134888 sec
# > running: current sample 58, gen_loss=0.7682604789733887, inst_loss=1.3696846961975098, time=30.31590962409973 sec
# > running: current sample 61, gen_loss=0.7782651782035828, inst_loss=1.3719282150268555, time=32.157076597213745 sec
# Epoch: 6
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xf9\xf9\xf9\xf8\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfa\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# [102 180 827 393 642 558]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.7814555168151855, inst_loss=1.3694263696670532, time=1.5054233074188232 sec
# > running: current sample 4, gen_loss=0.794427216053009, inst_loss=1.367870807647705, time=3.0299088954925537 sec
# > running: current sample 7, gen_loss=0.7795016765594482, inst_loss=1.3750004768371582, time=4.577854633331299 sec
# > running: current sample 10, gen_loss=0.7658571600914001, inst_loss=1.3777837753295898, time=6.078367471694946 sec
# > running: current sample 13, gen_loss=0.773259699344635, inst_loss=1.3737409114837646, time=7.570601940155029 sec
# > running: current sample 16, gen_loss=0.7766380310058594, inst_loss=1.3761112689971924, time=9.075896263122559 sec
# > running: current sample 19, gen_loss=0.7971823811531067, inst_loss=1.379023790359497, time=10.573051929473877 sec
# > running: current sample 22, gen_loss=0.7900559902191162, inst_loss=1.389561414718628, time=12.080198287963867 sec
# > running: current sample 25, gen_loss=0.7668590545654297, inst_loss=1.3689323663711548, time=13.57163143157959 sec
# > running: current sample 28, gen_loss=0.7718262672424316, inst_loss=1.3841447830200195, time=15.094006061553955 sec
# > running: current sample 31, gen_loss=0.7639708518981934, inst_loss=1.3819005489349365, time=16.638015747070312 sec
# > running: current sample 34, gen_loss=0.7491410374641418, inst_loss=1.3860430717468262, time=18.124557733535767 sec
# > running: current sample 37, gen_loss=0.7282330989837646, inst_loss=1.3909213542938232, time=19.625198125839233 sec
# > running: current sample 40, gen_loss=0.7265070080757141, inst_loss=1.3989272117614746, time=21.118841648101807 sec
# > running: current sample 43, gen_loss=0.7005669474601746, inst_loss=1.4014664888381958, time=22.61837387084961 sec
# > running: current sample 46, gen_loss=0.695222795009613, inst_loss=1.3984463214874268, time=24.124542713165283 sec
# > running: current sample 49, gen_loss=0.6909800171852112, inst_loss=1.402972936630249, time=25.625014543533325 sec
# > running: current sample 52, gen_loss=0.6717481017112732, inst_loss=1.3891170024871826, time=27.152735471725464 sec
# > running: current sample 55, gen_loss=0.6537197232246399, inst_loss=1.3789234161376953, time=28.65694546699524 sec
# > running: current sample 58, gen_loss=0.6514238715171814, inst_loss=1.3793706893920898, time=30.170271158218384 sec
# > running: current sample 61, gen_loss=0.6388360857963562, inst_loss=1.3696506023406982, time=31.66512680053711 sec
# Epoch: 7
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf8\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfa\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfa\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf9\…
# [364 538 266 745 714 759]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.6337046027183533, inst_loss=1.3615227937698364, time=1.8446016311645508 sec
# > running: current sample 4, gen_loss=0.629770040512085, inst_loss=1.3585491180419922, time=3.383960008621216 sec
# > running: current sample 7, gen_loss=0.6220747828483582, inst_loss=1.3445558547973633, time=4.906667470932007 sec
# > running: current sample 10, gen_loss=0.61372971534729, inst_loss=1.33902907371521, time=6.41975474357605 sec
# > running: current sample 13, gen_loss=0.6191927194595337, inst_loss=1.3335462808609009, time=7.910758018493652 sec
# > running: current sample 16, gen_loss=0.6098571419715881, inst_loss=1.3246046304702759, time=9.425450801849365 sec
# > running: current sample 19, gen_loss=0.6114709973335266, inst_loss=1.319199800491333, time=10.94596266746521 sec
# > running: current sample 22, gen_loss=0.5970527529716492, inst_loss=1.3110328912734985, time=12.445581197738647 sec
# > running: current sample 25, gen_loss=0.6184231638908386, inst_loss=1.3216772079467773, time=13.946999073028564 sec
# > running: current sample 28, gen_loss=0.6410780549049377, inst_loss=1.30539071559906, time=15.516189813613892 sec
# > running: current sample 31, gen_loss=0.6346635222434998, inst_loss=1.302919626235962, time=17.062222719192505 sec
# > running: current sample 34, gen_loss=0.6652233004570007, inst_loss=1.2743842601776123, time=18.59467101097107 sec
# > running: current sample 37, gen_loss=0.886003315448761, inst_loss=1.331451177597046, time=20.127615451812744 sec
# > running: current sample 40, gen_loss=1.2345951795578003, inst_loss=1.4625753164291382, time=21.639040231704712 sec
# > running: current sample 43, gen_loss=1.0595957040786743, inst_loss=1.3438642024993896, time=23.15478539466858 sec
# > running: current sample 46, gen_loss=0.7589349746704102, inst_loss=1.3658018112182617, time=24.656916618347168 sec
# > running: current sample 49, gen_loss=0.6691767573356628, inst_loss=1.3799164295196533, time=26.160212755203247 sec
# > running: current sample 52, gen_loss=0.6108603477478027, inst_loss=1.4025553464889526, time=27.7408390045166 sec
# > running: current sample 55, gen_loss=0.5496444702148438, inst_loss=1.457966923713684, time=29.250858545303345 sec
# > running: current sample 58, gen_loss=0.5885295271873474, inst_loss=1.4526846408843994, time=30.750231742858887 sec
# > running: current sample 61, gen_loss=0.5988035202026367, inst_loss=1.4952178001403809, time=32.2751042842865 sec
# Epoch: 8
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfb\xfb\xfb\xf9\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfc\xfc\xfc\xfb\xfb\xfb\xf9\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# [502 885 637 455 105 319]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.5123568177223206, inst_loss=1.5709202289581299, time=1.527101993560791 sec
# > running: current sample 4, gen_loss=0.5917561054229736, inst_loss=1.5610461235046387, time=3.4286327362060547 sec
# > running: current sample 7, gen_loss=0.6894800066947937, inst_loss=1.4996986389160156, time=4.923156261444092 sec
# > running: current sample 10, gen_loss=0.6894163489341736, inst_loss=1.5210298299789429, time=6.443618535995483 sec
# > running: current sample 13, gen_loss=0.6941266059875488, inst_loss=1.52883780002594, time=7.960208892822266 sec
# > running: current sample 16, gen_loss=0.7264013290405273, inst_loss=1.5200355052947998, time=9.467350244522095 sec
# > running: current sample 19, gen_loss=0.7652327418327332, inst_loss=1.4974005222320557, time=10.99201488494873 sec
# > running: current sample 22, gen_loss=0.8034809231758118, inst_loss=1.4769102334976196, time=12.500406742095947 sec
# > running: current sample 25, gen_loss=0.7999253273010254, inst_loss=1.467453956604004, time=14.038242816925049 sec
# > running: current sample 28, gen_loss=0.7913660407066345, inst_loss=1.454040288925171, time=15.551974058151245 sec
# > running: current sample 31, gen_loss=0.7915394306182861, inst_loss=1.431617021560669, time=17.054096698760986 sec
# > running: current sample 34, gen_loss=0.7844668030738831, inst_loss=1.4082818031311035, time=18.56234574317932 sec
# > running: current sample 37, gen_loss=0.7800948023796082, inst_loss=1.3774158954620361, time=20.082234382629395 sec
# > running: current sample 40, gen_loss=0.7482993602752686, inst_loss=1.373487114906311, time=21.61840271949768 sec
# > running: current sample 43, gen_loss=0.7655532956123352, inst_loss=1.3214898109436035, time=23.13198184967041 sec
# > running: current sample 46, gen_loss=0.7703702449798584, inst_loss=1.283524990081787, time=24.643094062805176 sec
# > running: current sample 49, gen_loss=0.7624251842498779, inst_loss=1.261430263519287, time=26.194146394729614 sec
# > running: current sample 52, gen_loss=0.7371330261230469, inst_loss=1.2515779733657837, time=27.72050952911377 sec
# > running: current sample 55, gen_loss=0.7061088681221008, inst_loss=1.2555872201919556, time=29.238096475601196 sec
# > running: current sample 58, gen_loss=0.7759449481964111, inst_loss=1.16531503200531, time=30.738322257995605 sec
# > running: current sample 61, gen_loss=0.7551999688148499, inst_loss=1.142812967300415, time=32.25392413139343 sec
# ...
# > running: current sample 31, gen_loss=0.9622724056243896, inst_loss=1.4764069318771362, time=16.855664491653442 sec
# > running: current sample 34, gen_loss=0.9212298393249512, inst_loss=1.4048395156860352, time=18.360777378082275 sec
# > running: current sample 37, gen_loss=0.911242663860321, inst_loss=1.4620022773742676, time=19.872524738311768 sec
# > running: current sample 40, gen_loss=0.7796463966369629, inst_loss=1.3717167377471924, time=21.38487672805786 sec
# > running: current sample 43, gen_loss=0.5961620807647705, inst_loss=1.448152780532837, time=22.88911461830139 sec
# > running: current sample 46, gen_loss=0.6898550987243652, inst_loss=1.3186578750610352, time=24.379423141479492 sec
# > running: current sample 49, gen_loss=0.6425982117652893, inst_loss=1.3560622930526733, time=25.946784257888794 sec
# > running: current sample 52, gen_loss=0.64610356092453, inst_loss=1.3274989128112793, time=27.449673891067505 sec
# > running: current sample 55, gen_loss=0.5606411695480347, inst_loss=1.4485015869140625, time=28.956022024154663 sec
# > running: current sample 58, gen_loss=0.5914750695228577, inst_loss=1.4248692989349365, time=30.46363878250122 sec
# > running: current sample 61, gen_loss=0.7048571705818176, inst_loss=1.4738192558288574, time=32.323044776916504 sec
# Epoch: 18
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf9\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xf9\xf9\xf9\xf4\…
# [282  38 587 576 741  67]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.7482842803001404, inst_loss=1.4506020545959473, time=1.5902509689331055 sec
# > running: current sample 4, gen_loss=0.8556849360466003, inst_loss=1.4782054424285889, time=3.1026113033294678 sec
# > running: current sample 7, gen_loss=0.9652265906333923, inst_loss=1.3575587272644043, time=4.611557722091675 sec
# > running: current sample 10, gen_loss=0.9031583666801453, inst_loss=1.4022612571716309, time=6.11267614364624 sec
# > running: current sample 13, gen_loss=1.0984188318252563, inst_loss=1.3016725778579712, time=7.633313179016113 sec
# > running: current sample 16, gen_loss=1.1866557598114014, inst_loss=1.1786617040634155, time=9.143840074539185 sec
# > running: current sample 19, gen_loss=0.6380513906478882, inst_loss=1.4138031005859375, time=10.638070106506348 sec
# > running: current sample 22, gen_loss=0.6446968913078308, inst_loss=1.4073338508605957, time=12.16599726676941 sec
# > running: current sample 25, gen_loss=0.6352377533912659, inst_loss=1.388136625289917, time=13.690676212310791 sec
# > running: current sample 28, gen_loss=0.6628994345664978, inst_loss=1.3779244422912598, time=15.201383590698242 sec
# > running: current sample 31, gen_loss=0.6612012982368469, inst_loss=1.370356798171997, time=16.702614307403564 sec
# > running: current sample 34, gen_loss=0.6751560568809509, inst_loss=1.3585807085037231, time=18.220446586608887 sec
# > running: current sample 37, gen_loss=0.7180802226066589, inst_loss=1.379343032836914, time=19.732833862304688 sec
# > running: current sample 40, gen_loss=0.7077770233154297, inst_loss=1.3411507606506348, time=21.229204177856445 sec
# > running: current sample 43, gen_loss=0.7368655204772949, inst_loss=1.3706886768341064, time=22.726075649261475 sec
# > running: current sample 46, gen_loss=0.7394376397132874, inst_loss=1.350754976272583, time=24.25214910507202 sec
# > running: current sample 49, gen_loss=0.735048770904541, inst_loss=1.355107069015503, time=25.803656816482544 sec
# > running: current sample 52, gen_loss=0.7717830538749695, inst_loss=1.3636198043823242, time=27.322463274002075 sec
# > running: current sample 55, gen_loss=0.787428081035614, inst_loss=1.346037745475769, time=28.8386390209198 sec
# > running: current sample 58, gen_loss=0.7934163212776184, inst_loss=1.3791042566299438, time=30.338133096694946 sec
# > running: current sample 61, gen_loss=0.8146769404411316, inst_loss=1.3854424953460693, time=31.849945068359375 sec
# Epoch: 19
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xfa\xfa\xfa\xf9\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xfb\…
# [608 530 627 629 219 468]
# (64, 19, 64, 64, 1) (64, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.8364900946617126, inst_loss=1.410699725151062, time=1.5265476703643799 sec
# > running: current sample 4, gen_loss=0.79061359167099, inst_loss=1.3791835308074951, time=3.050494432449341 sec
# > running: current sample 7, gen_loss=0.7505490183830261, inst_loss=1.362351655960083, time=4.8904993534088135 sec
# > running: current sample 10, gen_loss=0.7598150372505188, inst_loss=1.3885178565979004, time=6.422796249389648 sec
# > running: current sample 13, gen_loss=0.702007532119751, inst_loss=1.409102439880371, time=7.922972917556763 sec
# > running: current sample 16, gen_loss=0.6657235026359558, inst_loss=1.399777889251709, time=9.439793586730957 sec
# > running: current sample 19, gen_loss=0.6407037973403931, inst_loss=1.4149117469787598, time=10.962435007095337 sec
# > running: current sample 22, gen_loss=0.6210541129112244, inst_loss=1.4079647064208984, time=12.530686855316162 sec
# > running: current sample 25, gen_loss=0.5949686169624329, inst_loss=1.3859667778015137, time=14.034844398498535 sec
# > running: current sample 28, gen_loss=0.5977938175201416, inst_loss=1.3949432373046875, time=15.5467369556427 sec
# > running: current sample 31, gen_loss=0.6183119416236877, inst_loss=1.3936927318572998, time=17.037176370620728 sec
# > running: current sample 34, gen_loss=0.6269343495368958, inst_loss=1.3868274688720703, time=18.554813385009766 sec
# > running: current sample 37, gen_loss=0.5843937993049622, inst_loss=1.4082876443862915, time=20.07495355606079 sec
# > running: current sample 40, gen_loss=0.6284814476966858, inst_loss=1.3840811252593994, time=21.594014406204224 sec
# > running: current sample 43, gen_loss=0.664405345916748, inst_loss=1.391137719154358, time=23.106651306152344 sec
# > running: current sample 46, gen_loss=0.6512941718101501, inst_loss=1.3903956413269043, time=24.701605796813965 sec
# > running: current sample 49, gen_loss=0.6615637540817261, inst_loss=1.369367003440857, time=26.238622188568115 sec
# > running: current sample 52, gen_loss=0.6755170226097107, inst_loss=1.3427845239639282, time=27.77002263069153 sec
# > running: current sample 55, gen_loss=0.6831720471382141, inst_loss=1.343324065208435, time=29.307432651519775 sec
# > running: current sample 58, gen_loss=0.6809446215629578, inst_loss=1.3333899974822998, time=30.830893754959106 sec
# > running: current sample 61, gen_loss=0.7409029006958008, inst_loss=1.322500467300415, time=32.366811990737915 sec
# Epoch: 20
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf7\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfb\xfb\xfb\xf8\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xf9\xf9\xf9\xf2\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfd\xfd\xfd\xfc\xfc\xfc\xfb\xfb\xfb\xfa\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xff\xff\xff\xfe\xfe\xfe\xfd\xfd\xfd\xfc\xfc\xfc\xf4\…
# CPU times: user 11min 53s, sys: 13.4 s, total: 12min 6s
# Wall time: 12min 16s

# %% [markdown]
# #### Ecoli

# %%
# %%time

# Epochs
NUM_OF_EP = 20
for iii in range(NUM_OF_EP):

    # Assuming x_train and y_train are already defined and loaded
    num_samples = 32
    indices = np.random.choice(x_train.shape[0], num_samples, replace=True)
    print(indices[0:6])
    x_train_sub = x_train[indices]
    y_train_sub = y_train[indices]
    print(x_train_sub.shape, y_train_sub.shape)

    # Example usage:
    BATCH_SIZE = 3
    if tf.test.gpu_device_name() != '':
        with tf.device('/device:GPU:0'):
            vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)
    else:
        vapaad_model.train(x_train_sub, y_train_sub, batch_size=BATCH_SIZE)

    print("Epoch: " + str(iii+1))

    # Assuming you have a method to get the trained generator
    trained_generator = vapaad_model.gen_main

    if True:
        # Create a directory for the GIFs
        gif_dir = "predicted_gifs_ecoli_instruct_vapaad_stop_grad"
        os.makedirs(gif_dir, exist_ok=True)

        # Select a few random examples from the dataset.
        examples = x_val[np.random.choice(range(len(x_val)), size=5)]

        # Iterate over the examples and predict the frames.
        predicted_videos = []
        for index, example in enumerate(examples):
            # Pick the first/last ten frames from the example.
            frames = example[:10, ...]
            original_frames = example[10:, ...]
            new_predictions = np.zeros(shape=(10, *frames[0].shape))

            # Predict a new set of 10 frames.
            for i in range(10):
                # Extract the generator's prediction and post-process it.
                frames = example[: 10 + i + 1, ...]
                new_prediction = trained_generator.predict(np.expand_dims(frames, axis=0))
                new_prediction = rescale_and_discretize(new_prediction)
                new_prediction = np.squeeze(new_prediction, axis=0)
                predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

                # Extend the set of prediction frames.
                new_predictions[i] = predicted_frame

            # Create and save GIFs for each of the ground truth/prediction images.
            for frame_set_idx, frame_set in enumerate([original_frames, new_predictions]):
                # Construct a GIF from the selected video frames.
                current_frames = np.squeeze(frame_set)
                current_frames = current_frames[..., np.newaxis] * np.ones(3)
                current_frames = (current_frames * 255).astype(np.uint8)
                current_frames = list(current_frames)

                # Define the GIF filepath
                gif_filename = os.path.join(gif_dir, f"example_{index}_{'original' if frame_set_idx == 0 else 'predicted'}.gif")

                # Save the GIF
                imageio.mimsave(gif_filename, current_frames, "GIF", duration=.9)

                # To display the videos inline, you can open and read the saved GIF
                with open(gif_filename, 'rb') as gif_file:
                    predicted_videos.append(gif_file.read())

        # Display the videos inline in the notebook.
        print("Truth\tPrediction")
        for i in range(0, len(predicted_videos), 2):
            box = HBox(
                [
                    widgets.Image(value=predicted_videos[i], format='gif'),
                    widgets.Image(value=predicted_videos[i + 1], format='gif'),
                ]
            )
            display(box)
# Out:
# [71 90 57 68 13 12]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.7022477984428406, inst_loss=1.3715925216674805, time=1.7529518604278564 sec
# > running: current sample 4, gen_loss=0.735912024974823, inst_loss=1.3395705223083496, time=3.397324562072754 sec
# > running: current sample 7, gen_loss=0.727855920791626, inst_loss=1.3446621894836426, time=5.0251171588897705 sec
# > running: current sample 10, gen_loss=0.7052077651023865, inst_loss=1.3622277975082397, time=6.714313745498657 sec
# > running: current sample 13, gen_loss=0.729280948638916, inst_loss=1.3523528575897217, time=8.384414911270142 sec
# > running: current sample 16, gen_loss=0.7436673045158386, inst_loss=1.3234933614730835, time=10.012645483016968 sec
# > running: current sample 19, gen_loss=0.7255821824073792, inst_loss=1.3396413326263428, time=11.63045072555542 sec
# > running: current sample 22, gen_loss=0.7134689688682556, inst_loss=1.344838261604309, time=13.282210350036621 sec
# > running: current sample 25, gen_loss=0.721426784992218, inst_loss=1.3361127376556396, time=14.941294193267822 sec
# > running: current sample 28, gen_loss=0.7353280186653137, inst_loss=1.3244181871414185, time=16.587280750274658 sec
# Epoch: 1
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc4\xc4\xc4\xc3\xc3\xc3\xc2\xc2\xc2\xc1\xc1\xc1\xc0\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc4\xc4\xc4\xc2\xc2\xc2\xc1\xc1\xc1\xc0\xc0\xc0\xab\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc2\xc2\xc2\xc1\xc1\xc1\xc0\xc0\xc0\xbf\xbf\xbf\xa8\…
# [130  11  72  37  94 125]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.7587687373161316, inst_loss=1.2965173721313477, time=1.6154654026031494 sec
# > running: current sample 4, gen_loss=0.763822078704834, inst_loss=1.3063673973083496, time=3.253941297531128 sec
# > running: current sample 7, gen_loss=0.787568986415863, inst_loss=1.2697575092315674, time=4.867023944854736 sec
# > running: current sample 10, gen_loss=0.818458616733551, inst_loss=1.2587908506393433, time=6.495699644088745 sec
# > running: current sample 13, gen_loss=0.8533363938331604, inst_loss=1.236072301864624, time=8.15116834640503 sec
# > running: current sample 16, gen_loss=0.8954210877418518, inst_loss=1.2103230953216553, time=9.75663948059082 sec
# > running: current sample 19, gen_loss=0.8997649550437927, inst_loss=1.206829309463501, time=11.799858093261719 sec
# > running: current sample 22, gen_loss=0.9190723299980164, inst_loss=1.1721429824829102, time=13.43314266204834 sec
# > running: current sample 25, gen_loss=0.9860436320304871, inst_loss=1.1229870319366455, time=15.049178123474121 sec
# > running: current sample 28, gen_loss=0.9921762943267822, inst_loss=1.1310348510742188, time=16.639408349990845 sec
# Epoch: 2
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc6\xc6\xc6\xc5\xc5\xc5\xc4\xc4\xc4\xc3\xc3\xc3\xc2\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# [67 87 86 17 23 20]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=1.0030627250671387, inst_loss=1.1760506629943848, time=1.6117019653320312 sec
# > running: current sample 4, gen_loss=0.9399567246437073, inst_loss=1.1726261377334595, time=3.1555092334747314 sec
# > running: current sample 7, gen_loss=0.9768271446228027, inst_loss=1.1476988792419434, time=4.71306037902832 sec
# > running: current sample 10, gen_loss=0.9116417765617371, inst_loss=1.1674318313598633, time=6.250197410583496 sec
# > running: current sample 13, gen_loss=0.823830783367157, inst_loss=1.215679407119751, time=7.776433706283569 sec
# > running: current sample 16, gen_loss=0.7020346522331238, inst_loss=1.2831465005874634, time=9.324626922607422 sec
# > running: current sample 19, gen_loss=0.6772584915161133, inst_loss=1.3020886182785034, time=10.900103092193604 sec
# > running: current sample 22, gen_loss=0.6545338034629822, inst_loss=1.3122162818908691, time=12.450789451599121 sec
# > running: current sample 25, gen_loss=0.6323633193969727, inst_loss=1.335040807723999, time=14.020113468170166 sec
# > running: current sample 28, gen_loss=0.7045571208000183, inst_loss=1.2529813051223755, time=15.610295534133911 sec
# Epoch: 3
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xca\xca\xca\xc9\xc9\xc9\xc8\xc8\xc8\xc7\xc7\xc7\xc6\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x85\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# [120  20  37 121  87  63]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.6422846913337708, inst_loss=1.3035764694213867, time=1.5996012687683105 sec
# > running: current sample 4, gen_loss=0.6371821165084839, inst_loss=1.3078588247299194, time=3.1358981132507324 sec
# > running: current sample 7, gen_loss=0.8188943862915039, inst_loss=1.148963451385498, time=4.6961164474487305 sec
# > running: current sample 10, gen_loss=0.7319428324699402, inst_loss=1.2277495861053467, time=6.293999433517456 sec
# > running: current sample 13, gen_loss=0.6887149810791016, inst_loss=1.2818856239318848, time=7.819676637649536 sec
# > running: current sample 16, gen_loss=0.7250661849975586, inst_loss=1.2419837713241577, time=9.342821598052979 sec
# > running: current sample 19, gen_loss=0.7281265258789062, inst_loss=1.250718116760254, time=10.87313461303711 sec
# > running: current sample 22, gen_loss=0.7831905484199524, inst_loss=1.2260639667510986, time=12.423794269561768 sec
# > running: current sample 25, gen_loss=0.7781206965446472, inst_loss=1.2158424854278564, time=13.942155599594116 sec
# > running: current sample 28, gen_loss=0.7985315918922424, inst_loss=1.1990337371826172, time=15.475629329681396 sec
# Epoch: 4
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc4\xc4\xc4\xc3\xc3\xc3\xc2\xc2\xc2\xc1\xc1\xc1\xc0\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# [119 109 113  51 136  97]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.8199916481971741, inst_loss=1.1748721599578857, time=1.6281719207763672 sec
# > running: current sample 4, gen_loss=0.7272278666496277, inst_loss=1.2359626293182373, time=3.221231460571289 sec
# > running: current sample 7, gen_loss=0.7160061001777649, inst_loss=1.2216546535491943, time=4.816437244415283 sec
# > running: current sample 10, gen_loss=0.7586860656738281, inst_loss=1.1867332458496094, time=6.397992372512817 sec
# > running: current sample 13, gen_loss=0.8627619743347168, inst_loss=1.083266019821167, time=7.99117374420166 sec
# > running: current sample 16, gen_loss=0.8562890887260437, inst_loss=1.0396925210952759, time=9.599814176559448 sec
# > running: current sample 19, gen_loss=0.8126532435417175, inst_loss=1.0334033966064453, time=11.183571100234985 sec
# > running: current sample 22, gen_loss=0.7938048243522644, inst_loss=1.0243343114852905, time=12.745820999145508 sec
# > running: current sample 25, gen_loss=0.7804294228553772, inst_loss=1.0159194469451904, time=14.307036638259888 sec
# > running: current sample 28, gen_loss=0.7200649380683899, inst_loss=1.0585370063781738, time=15.878785848617554 sec
# Epoch: 5
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 59ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\xc4\xc4\xc3\…
# [ 15  42  93 117  86  39]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=0.9193248152732849, inst_loss=0.912854790687561, time=1.5901522636413574 sec
# > running: current sample 4, gen_loss=1.0471707582473755, inst_loss=0.8077592849731445, time=3.158926010131836 sec
# > running: current sample 7, gen_loss=1.0821353197097778, inst_loss=0.8062930107116699, time=4.729967355728149 sec
# > running: current sample 10, gen_loss=1.2227681875228882, inst_loss=0.7122236490249634, time=6.308208703994751 sec
# > running: current sample 13, gen_loss=1.208531141281128, inst_loss=0.7147601842880249, time=7.906031608581543 sec
# > running: current sample 16, gen_loss=1.2231862545013428, inst_loss=0.7093876600265503, time=9.500452280044556 sec
# > running: current sample 19, gen_loss=1.2282401323318481, inst_loss=0.6577634811401367, time=11.0615975856781 sec
# > running: current sample 22, gen_loss=1.2376580238342285, inst_loss=0.6306307315826416, time=12.613546371459961 sec
# > running: current sample 25, gen_loss=1.1559170484542847, inst_loss=0.6565515995025635, time=14.18258547782898 sec
# > running: current sample 28, gen_loss=1.4116729497909546, inst_loss=0.5444421172142029, time=15.74690318107605 sec
# Epoch: 6
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xba\xba\xba\x98\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x85\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# [ 43  23 122  87 102  71]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=1.1751972436904907, inst_loss=0.616791307926178, time=1.6017496585845947 sec
# > running: current sample 4, gen_loss=1.4820276498794556, inst_loss=0.5262186527252197, time=3.1525156497955322 sec
# > running: current sample 7, gen_loss=1.4756613969802856, inst_loss=0.5390058755874634, time=4.701927423477173 sec
# > running: current sample 10, gen_loss=1.4188228845596313, inst_loss=0.5495803356170654, time=6.660180568695068 sec
# > running: current sample 13, gen_loss=1.4222337007522583, inst_loss=0.5137446522712708, time=8.218262195587158 sec
# > running: current sample 16, gen_loss=1.757142424583435, inst_loss=0.5210728645324707, time=9.810242414474487 sec
# > running: current sample 19, gen_loss=1.5364094972610474, inst_loss=0.47224879264831543, time=11.457690715789795 sec
# > running: current sample 22, gen_loss=1.9350045919418335, inst_loss=0.3385816216468811, time=13.040880680084229 sec
# > running: current sample 25, gen_loss=1.7463699579238892, inst_loss=0.4057518243789673, time=14.600127935409546 sec
# > running: current sample 28, gen_loss=2.9353010654449463, inst_loss=0.24509653449058533, time=16.177783250808716 sec
# Epoch: 7
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 62ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc6\xc6\xc6\xc5\xc5\xc5\xc4\xc4\xc4\xc3\xc3\xc3\xc2\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc6\xc6\xc6\xc5\xc5\xc5\xc4\xc4\xc4\xc3\xc3\xc3\xc2\…
# [ 73  63  39  88  59 105]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=3.4241676330566406, inst_loss=0.22316353023052216, time=1.6814978122711182 sec
# > running: current sample 4, gen_loss=5.013180732727051, inst_loss=0.16807657480239868, time=3.238884925842285 sec
# > running: current sample 7, gen_loss=4.751602649688721, inst_loss=0.18562071025371552, time=4.794089078903198 sec
# > running: current sample 10, gen_loss=4.436295986175537, inst_loss=0.1451781988143921, time=6.353015184402466 sec
# > running: current sample 13, gen_loss=3.6372787952423096, inst_loss=0.1498766541481018, time=7.888941526412964 sec
# > running: current sample 16, gen_loss=2.37249755859375, inst_loss=0.16579389572143555, time=9.445613622665405 sec
# > running: current sample 19, gen_loss=2.376682996749878, inst_loss=0.2146466225385666, time=10.97262716293335 sec
# > running: current sample 22, gen_loss=2.5401132106781006, inst_loss=0.15202981233596802, time=12.548583269119263 sec
# > running: current sample 25, gen_loss=2.470423936843872, inst_loss=0.20349863171577454, time=14.151082038879395 sec
# > running: current sample 28, gen_loss=2.294726610183716, inst_loss=0.5522215366363525, time=15.675209522247314 sec
# Epoch: 8
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xba\xba\xba\x98\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\xc4\xc4\xc3\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xca\xca\xca\xc9\xc9\xc9\xc8\xc8\xc8\xc7\xc7\xc7\xc6\…
# [114 117 120  19  11 128]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=1.7345401048660278, inst_loss=0.42763569951057434, time=1.5465281009674072 sec
# > running: current sample 4, gen_loss=3.385857343673706, inst_loss=0.33557426929473877, time=3.0758018493652344 sec
# > running: current sample 7, gen_loss=3.479696273803711, inst_loss=0.2019968032836914, time=4.645036458969116 sec
# > running: current sample 10, gen_loss=5.095385551452637, inst_loss=0.23775970935821533, time=6.205490350723267 sec
# > running: current sample 13, gen_loss=4.543186187744141, inst_loss=0.4249652028083801, time=7.762098789215088 sec
# > running: current sample 16, gen_loss=4.465691566467285, inst_loss=0.06930830329656601, time=9.276822805404663 sec
# > running: current sample 19, gen_loss=2.55059552192688, inst_loss=0.1434450000524521, time=10.787813425064087 sec
# > running: current sample 22, gen_loss=3.625653028488159, inst_loss=0.37979698181152344, time=12.307299613952637 sec
# > running: current sample 25, gen_loss=2.549830675125122, inst_loss=0.2764809727668762, time=13.82344937324524 sec
# > running: current sample 28, gen_loss=4.418328762054443, inst_loss=0.09240151196718216, time=15.76475191116333 sec
# Epoch: 9
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x85\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xba\xba\xba\x98\…
# [ 79  73   5  69 130 112]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=3.237759828567505, inst_loss=0.18866035342216492, time=1.5809614658355713 sec
# > running: current sample 4, gen_loss=5.249972343444824, inst_loss=0.5617325305938721, time=3.1528120040893555 sec
# > running: current sample 7, gen_loss=2.559784173965454, inst_loss=0.2488294541835785, time=4.723504066467285 sec
# > running: current sample 10, gen_loss=2.6640539169311523, inst_loss=0.1746765673160553, time=6.283831596374512 sec
# > running: current sample 13, gen_loss=1.71695077419281, inst_loss=0.37424907088279724, time=7.890401601791382 sec
# > running: current sample 16, gen_loss=4.280069828033447, inst_loss=0.1741965264081955, time=9.451767444610596 sec
# > running: current sample 19, gen_loss=3.2693183422088623, inst_loss=0.1608356088399887, time=10.981241464614868 sec
# > running: current sample 22, gen_loss=3.566476821899414, inst_loss=0.12438492476940155, time=12.593505859375 sec
# > running: current sample 25, gen_loss=4.27692985534668, inst_loss=0.0933118686079979, time=14.124253988265991 sec
# > running: current sample 28, gen_loss=4.9381537437438965, inst_loss=0.23514743149280548, time=15.642913579940796 sec
# Epoch: 10
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xdf\xdf\xdf\xdd\xdd\xdd\xdb\xdb\xdb\xcf\xcf\xcf\xce\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# [92 71 71 13 82 11]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=6.03057336807251, inst_loss=0.06822274625301361, time=1.5707998275756836 sec
# > running: current sample 4, gen_loss=4.698627948760986, inst_loss=0.037822071462869644, time=3.1505069732666016 sec
# > running: current sample 7, gen_loss=2.378800392150879, inst_loss=0.19502049684524536, time=4.697563409805298 sec
# > running: current sample 10, gen_loss=4.021577835083008, inst_loss=0.06296303868293762, time=6.275071382522583 sec
# > running: current sample 13, gen_loss=2.3060169219970703, inst_loss=0.36292845010757446, time=7.8340044021606445 sec
# > running: current sample 16, gen_loss=4.395726680755615, inst_loss=0.07865869998931885, time=9.421022415161133 sec
# > running: current sample 19, gen_loss=1.5232361555099487, inst_loss=0.7220920324325562, time=11.011139631271362 sec
# > running: current sample 22, gen_loss=4.253752708435059, inst_loss=0.7619897723197937, time=12.62708592414856 sec
# > running: current sample 25, gen_loss=2.328083038330078, inst_loss=0.6416139006614685, time=14.166137933731079 sec
# > running: current sample 28, gen_loss=1.5162955522537231, inst_loss=0.4882040023803711, time=15.712122917175293 sec
# Epoch: 11
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# Truth	Prediction
# ...
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x85\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# [129  66 133  34  87 125]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=4.289591312408447, inst_loss=0.20080335438251495, time=1.5708568096160889 sec
# > running: current sample 4, gen_loss=3.601795196533203, inst_loss=0.18033535778522491, time=3.124985694885254 sec
# > running: current sample 7, gen_loss=3.9742777347564697, inst_loss=0.33837467432022095, time=4.641803741455078 sec
# > running: current sample 10, gen_loss=4.57146692276001, inst_loss=0.6169703006744385, time=6.183250427246094 sec
# > running: current sample 13, gen_loss=2.349118947982788, inst_loss=0.22419585287570953, time=7.700236558914185 sec
# > running: current sample 16, gen_loss=1.276389718055725, inst_loss=0.47839653491973877, time=9.231529712677002 sec
# > running: current sample 19, gen_loss=1.2192269563674927, inst_loss=0.4649413526058197, time=10.79695749282837 sec
# > running: current sample 22, gen_loss=2.148343086242676, inst_loss=0.42697352170944214, time=12.342182636260986 sec
# > running: current sample 25, gen_loss=1.4101861715316772, inst_loss=0.38104772567749023, time=13.861319065093994 sec
# > running: current sample 28, gen_loss=2.8746140003204346, inst_loss=0.16182975471019745, time=15.43256425857544 sec
# Epoch: 18
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xca\xca\xca\xc9\xc9\xc9\xc8\xc8\xc8\xc7\xc7\xc7\xc6\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xba\xba\xba\xa2\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x85\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# [ 73 117  26  83  69  68]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=2.436931848526001, inst_loss=0.15967096388339996, time=1.6083347797393799 sec
# > running: current sample 4, gen_loss=2.8740170001983643, inst_loss=0.26626116037368774, time=3.1824450492858887 sec
# > running: current sample 7, gen_loss=3.8932268619537354, inst_loss=0.380859911441803, time=5.204273223876953 sec
# > running: current sample 10, gen_loss=3.1917943954467773, inst_loss=0.18511375784873962, time=6.742326259613037 sec
# > running: current sample 13, gen_loss=3.5133056640625, inst_loss=0.08167824149131775, time=8.309856414794922 sec
# > running: current sample 16, gen_loss=1.878719449043274, inst_loss=0.18844807147979736, time=9.876756429672241 sec
# > running: current sample 19, gen_loss=2.1460580825805664, inst_loss=0.46443355083465576, time=11.437280178070068 sec
# > running: current sample 22, gen_loss=2.888934373855591, inst_loss=0.08568141609430313, time=13.007749319076538 sec
# > running: current sample 25, gen_loss=3.423381805419922, inst_loss=0.09087889641523361, time=14.645133972167969 sec
# > running: current sample 28, gen_loss=2.7224113941192627, inst_loss=0.22907981276512146, time=16.196401596069336 sec
# Epoch: 19
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc4\xc4\xc4\xc2\xc2\xc2\xc1\xc1\xc1\xc0\xc0\xc0\xab\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xba\xba\xba\xa2\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc8\xc8\xc8\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc4\xc4\xc4\xc3\xc3\xc3\xc2\xc2\xc2\xc1\xc1\xc1\xc0\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# [122  36  20   1  18  37]
# (32, 19, 64, 64, 1) (32, 19, 64, 64, 1)
# > running: current sample 1, gen_loss=3.6742208003997803, inst_loss=0.1679629683494568, time=1.6031346321105957 sec
# > running: current sample 4, gen_loss=3.5078258514404297, inst_loss=0.1612936556339264, time=3.16825270652771 sec
# > running: current sample 7, gen_loss=3.307920455932617, inst_loss=0.10882116854190826, time=4.8355185985565186 sec
# > running: current sample 10, gen_loss=2.514437437057495, inst_loss=0.13005328178405762, time=6.422744512557983 sec
# > running: current sample 13, gen_loss=2.6632556915283203, inst_loss=0.10356296598911285, time=7.996042966842651 sec
# > running: current sample 16, gen_loss=2.1097357273101807, inst_loss=0.22717584669589996, time=9.56506085395813 sec
# > running: current sample 19, gen_loss=3.4479267597198486, inst_loss=0.0722091794013977, time=11.11044692993164 sec
# > running: current sample 22, gen_loss=3.7598583698272705, inst_loss=0.06392117589712143, time=12.668349504470825 sec
# > running: current sample 25, gen_loss=3.6867897510528564, inst_loss=0.07539979368448257, time=14.221027851104736 sec
# > running: current sample 28, gen_loss=3.3906326293945312, inst_loss=0.12587770819664001, time=15.78346872329712 sec
# Epoch: 20
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xca\xca\xca\xc9\xc9\xc9\xc8\xc8\xc8\xc7\xc7\xc7\xc6\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\xc4\xc4\xc3\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xc7\xc7\xc7\xc6\xc6\xc6\xc5\xc5\xc5\xc4\xc4\xc4\xc3\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x86\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x85\x00\x00\xbe\xbe\xbe\xbd\xbd\xbd\xbc\xbc\xbc\xbb\xbb\xbb\xba\…
# CPU times: user 6min 37s, sys: 8.49 s, total: 6min 46s
# Wall time: 6min 56s
